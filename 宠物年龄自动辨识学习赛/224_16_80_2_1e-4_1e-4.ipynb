# %%
import os
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import shutil
from datetime import datetime
from zoneinfo import ZoneInfo
import numpy as np

# --- 全局常量与定义 ---
ANNOTATION_PATH = '/kaggle/input/cleandata/clean/annotations/'
TRAIN_IMG_PATH = '/kaggle/input/cleandata/clean/trainset/'
VAL_IMG_PATH = '/kaggle/input/cleandata/clean/valset/'
OUTPUT_PATH = '/kaggle/working/'
WEIGHTS_PATH = '/kaggle/input/bestmodel/pytorch/default/1/best_model.pth'
IMG_SIZE = 224
BATCH_SIZE = 16
NUM_EPOCHS = 80  # 延长到 80 个周期
WARMUP_EPOCHS = 2
L2_LAMBDA = 1e-4
BASE_LR = 1e-4

# --- 函数与类的定义 ---
def parse_txt_to_df(txt_path):
    """从 txt 文件解析数据到 DataFrame"""
    uuids = []
    ages = []
    try:
        with open(txt_path, 'r') as f:
            for line in f.readlines():
                line = line.strip()
                if line:
                    parts = line.split()
                    uuids.append(parts[0])
                    ages.append(int(parts[-1]))
    except FileNotFoundError:
        print(f"错误: 未找到文件 {txt_path}")
        return pd.DataFrame({'uuid': [], 'age': []})
    df = pd.DataFrame({'uuid': uuids, 'age': ages})
    return df

class PetAgeDataset(Dataset):
    """自定义的 PyTorch 数据集类"""
    def __init__(self, df, img_dir, transform=None):
        self.df = df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.loc[idx, 'uuid']
        img_path = os.path.join(self.img_dir, img_name)
        try:
            image = Image.open(img_path).convert('RGB')
        except FileNotFoundError:
            print(f"警告: 图像 {img_path} 未找到，跳过")
            return None, None
        label = self.df.loc[idx, 'age']
        if self.transform:
            image = self.transform(image)
        return image, torch.tensor(label, dtype=torch.float32)

class WeightedL1Loss(nn.Module):
    """加权 L1 损失，加入标签平滑和 L2 正则化"""
    def __init__(self, weights, smoothing=0.1, l2_lambda=0.0):
        super(WeightedL1Loss, self).__init__()
        self.weights = weights
        self.smoothing = smoothing
        self.l2_lambda = l2_lambda

    def forward(self, outputs, targets, model):
        weights = self.weights[targets.long()]
        smoothed_targets = targets * (1 - self.smoothing) + self.smoothing * targets.mean()
        l1_loss = torch.mean(torch.abs(outputs - smoothed_targets) * weights)
        if self.l2_lambda > 0:
            l2_loss = 0
            for param in model.parameters():
                if param.requires_grad:
                    l2_loss += torch.norm(param, p=2) ** 2
            l1_loss += self.l2_lambda * l2_loss
        return l1_loss

def linear_warmup_scheduler(optimizer, epoch, warmup_epochs, base_lr):
    """线性学习率预热"""
    if epoch < warmup_epochs:
        lr = base_lr * (epoch + 1) / warmup_epochs
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
    return optimizer.param_groups[0]['lr']

def count_trainable_parameters(model):
    """计算模型中可训练参数的数量"""
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def main():
    """主执行函数"""
    print("步骤 1: 项目设置...")
    train_transform = transforms.Compose([
        transforms.RandomResizedCrop(IMG_SIZE, scale=(0.6, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(20),
        transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.2),
        transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), scale=(0.8, 1.2)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    val_transform = transforms.Compose([
        transforms.Resize((IMG_SIZE, IMG_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    print("步骤 2: 解析并加载数据...")
    train_df = parse_txt_to_df(os.path.join(ANNOTATION_PATH, 'train.txt'))
    val_df = parse_txt_to_df(os.path.join(ANNOTATION_PATH, 'val.txt'))
    
    if train_df.empty or val_df.empty:
        print("错误: 训练集或验证集为空，程序退出")
        return
    
    # 去除年龄 ≥192 的噪声样本
    before_train = len(train_df)
    train_df = train_df[train_df['age'] < 192].reset_index(drop=True)
    removed_train = before_train - len(train_df)
    print(f"  - 已过滤训练集噪声样本: {removed_train} / {before_train} (≈{removed_train/before_train:.1%})")
    
    before_val = len(val_df)
    val_df = val_df[val_df['age'] < 192].reset_index(drop=True)
    removed_val = before_val - len(val_df)
    print(f"  - 已过滤验证集噪声样本: {removed_val} / {before_val} (≈{removed_val/before_val:.1%})")
    print(f"  - 找到 {len(train_df)} 个训练样本。")
    print(f"  - 找到 {len(val_df)} 个验证样本。")
     
    print("训练集年龄分布：\n", train_df['age'].describe())
    print("验证集年龄分布：\n", val_df['age'].describe())

    # 计算加权损失的权重
    age_counts = train_df['age'].value_counts().sort_index()
    max_age = int(max(train_df['age'].max(), val_df['age'].max())) + 1
    weights = torch.ones(max_age, dtype=torch.float32)
    for age in age_counts.index:
        weights[age] = min(2.0 / (age_counts[age] / len(train_df)), 25.0)
    weights = weights / weights.sum() * max_age

    train_dataset = PetAgeDataset(train_df, TRAIN_IMG_PATH, transform=train_transform)
    val_dataset = PetAgeDataset(val_df, VAL_IMG_PATH, transform=val_transform)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=1, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=1)

    print("步骤 3: 定义模型...")
    model = models.resnet34(weights=None)
    num_ftrs = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Dropout(0.6),
        nn.Linear(num_ftrs, 1)
    )
    # 加载本地权重
    try:
        state_dict = torch.load(WEIGHTS_PATH, map_location=torch.device('cpu'))
        model.load_state_dict(state_dict, strict=False)
        print(f"  - 成功加载权重文件: {WEIGHTS_PATH}")
        print(f"  - 加载的 fc 层参数: {[k for k in state_dict.keys() if 'fc' in k]}")
    except Exception as e:
        print(f"  - 加载权重失败: {e}. 将继续使用随机初始化权重训练...")
    
    # 冻结卷积层，仅微调 layer4 和 fc
    for name, param in model.named_parameters():
        if 'layer4' not in name and 'fc' not in name:
            param.requires_grad = False
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    print(f"  - 模型已移至: {device}")
    print(f"  - 可训练参数数量: {count_trainable_parameters(model)}")

    print("步骤 4: 开始训练...")
    criterion = WeightedL1Loss(weights.to(device), smoothing=0.1, l2_lambda=L2_LAMBDA)
    optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=BASE_LR, weight_decay=1e-2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
    train_mae_history = []
    val_mae_history = []
    grad_norms = []
    tta_variances = []
    best_val_mae = float('inf')
    best_epoch = 0

    for epoch in range(NUM_EPOCHS):
        # 学习率预热
        current_lr = linear_warmup_scheduler(optimizer, epoch, WARMUP_EPOCHS, base_lr=BASE_LR)
        
        model.train()
        train_loop = tqdm(train_loader, desc=f"训练 Epoch [{epoch+1}/{NUM_EPOCHS}]")
        running_loss = 0.0
        train_mae = 0.0
        for images, labels in train_loop:
            if images is None or labels is None:
                continue
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).squeeze()
            outputs = torch.clamp(outputs, 0, max_age)
            loss = criterion(outputs, labels, model)
            loss.backward()
            grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0).item()
            optimizer.step()
            running_loss += loss.item() * images.size(0)
            train_mae += torch.abs(outputs - labels).sum().item()
            train_loop.set_postfix(loss=loss.item(), lr=current_lr, grad_norm=grad_norm)

        train_epoch_loss = running_loss / len(train_dataset)
        train_epoch_mae = train_mae / len(train_dataset)
        grad_norms.append(grad_norm)

        model.eval()
        val_loop = tqdm(val_loader, desc=f"验证 Epoch [{epoch+1}/{NUM_EPOCHS}]")
        val_mae = 0.0
        val_predictions = []
        val_labels = []
        batch_tta_variances = []
        with torch.no_grad():
            for images, labels in val_loop:
                if images is None or labels is None:
                    continue
                images, labels = images.to(device), labels.to(device)
                # TTA: 原始图像 + 水平翻转
                outputs_orig = model(images).squeeze()
                outputs_flip = model(torch.flip(images, dims=[3])).squeeze()
                outputs = (outputs_orig + outputs_flip) / 2.0
                outputs = torch.clamp(outputs, 0, max_age)
                # 计算 TTA 预测方差
                batch_variance = torch.var(torch.stack([outputs_orig, outputs_flip]), dim=0).mean().item()
                batch_tta_variances.append(batch_variance)
                val_mae += torch.abs(outputs - labels).sum().item()
                val_predictions.extend(outputs.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_epoch_mae = val_mae / len(val_dataset)
        avg_tta_variance = sum(batch_tta_variances) / len(batch_tta_variances) if batch_tta_variances else 0
        tta_variances.append(avg_tta_variance)
        if val_epoch_mae == 0:
            print("警告: 验证MAE为0，可能存在预测问题")
        train_mae_history.append(train_epoch_mae)
        val_mae_history.append(val_epoch_mae)
        print(f"Epoch [{epoch+1}/{NUM_EPOCHS}] -> 训练损失: {train_epoch_loss:.4f}, 训练MAE: {train_epoch_mae:.4f}, 验证MAE: {val_epoch_mae:.4f}, 学习率: {current_lr:.6f}, 梯度范数: {grad_norm:.4f}, TTA方差: {avg_tta_variance:.4f}")

        # 保存当前模型
        timestamp = datetime.now(ZoneInfo("Asia/Singapore")).strftime("%Y%m%d_%H%M%S")
        torch.save(model.state_dict(), os.path.join(OUTPUT_PATH, f'model_epoch_{epoch+1}_{timestamp}.pth'))
        if val_epoch_mae < best_val_mae:
            best_val_mae = val_epoch_mae
            best_epoch = epoch + 1
            shutil.copy(os.path.join(OUTPUT_PATH, f'model_epoch_{epoch+1}_{timestamp}.pth'), os.path.join(OUTPUT_PATH, 'best_model.pth'))
            print(f"  - 验证集MAE提升至 {val_epoch_mae:.4f}。保存最佳模型: best_model.pth")

        # 仅在预热结束后应用余弦退火
        if epoch >= WARMUP_EPOCHS:
            scheduler.step()

    print(f"\n训练完成。最佳验证集MAE: {best_val_mae:.4f} (Epoch {best_epoch})")

    # 绘制 MAE 曲线
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, len(train_mae_history) + 1), train_mae_history, label='Train MAE')
    plt.plot(range(1, len(val_mae_history) + 1), val_mae_history, label='Validation MAE')
    plt.xlabel('Epoch')
    plt.ylabel('MAE (months)')
    plt.legend()
    plt.savefig(os.path.join(OUTPUT_PATH, 'mae_curve.png'))
    plt.show()

    # 绘制梯度范数曲线
    plt.figure(figsize=(10, 5))
    plt.plot(range(1, len(grad_norms) + 1), grad_norms, label='Gradient Norm')
    plt.xlabel('Epoch')
    plt.ylabel('Gradient Norm')
    plt.legend()
    plt.savefig(os.path.join(OUTPUT_PATH, 'grad_norm.png'))
    plt.show()

    # 绘制预测 vs 真实年龄散点图
    plt.figure(figsize=(10, 5))
    plt.scatter(val_labels, val_predictions, alpha=0.5)
    plt.plot([min(val_labels), max(val_labels)], [min(val_labels), max(val_labels)], 'r--')
    plt.xlabel('True Age (months)')
    plt.ylabel('Predicted Age (months)')
    plt.title('Predicted vs True Age')
    plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_true.png'))
    plt.show()

    # 分析误差分布
    errors = [abs(pred - true) for pred, true in zip(val_predictions, val_labels)]
    plt.hist(errors, bins=30)
    plt.xlabel('Absolute Error (months)')
    plt.ylabel('Count')
    plt.savefig(os.path.join(OUTPUT_PATH, 'error_distribution.png'))
    plt.show()
    print("验证集误差分布统计：\n", pd.Series(errors).describe())

    # 保存 TTA 方差统计
    tta_stats = pd.Series(tta_variances)
    tta_stats.to_csv(os.path.join(OUTPUT_PATH, 'tta_variance.csv'), header=['variance'], index_label='epoch')
    print("TTA方差统计：\n", tta_stats.describe())

    # 年龄分段误差分析
    val_df_pred = pd.DataFrame({'true_age': val_labels, 'pred_age': val_predictions})
    bins = pd.qcut(val_df_pred['true_age'], q=4, duplicates='drop')
    val_df_pred['age_bin'] = bins
    error_by_bin = val_df_pred.groupby('age_bin', observed=True).apply(
        lambda x: pd.Series({
            'mean_error': (x['pred_age'] - x['true_age']).abs().mean(),
            'count': len(x)
        }), include_groups=False
    )
    print("按年龄分段的平均误差：\n", error_by_bin)
    error_by_bin.to_csv(os.path.join(OUTPUT_PATH, 'error_by_age_bin.csv'), encoding='utf-8')

    print("\n步骤 5: 最终评估与结果展示...")
    try:
        model.load_state_dict(torch.load(os.path.join(OUTPUT_PATH, 'best_model.pth')))
        print(f"  - 成功加载最佳模型: best_model.pth")
    except FileNotFoundError:
        print(f"  - 未找到最佳模型文件: best_model.pth，尝试加载最后模型")
        try:
            model.load_state_dict(torch.load(os.path.join(OUTPUT_PATH, f'model_epoch_{best_epoch}_{timestamp}.pth')))
            print(f"  - 成功加载最后模型: model_epoch_{best_epoch}_{timestamp}.pth")
        except FileNotFoundError:
            print(f"  - 未找到任何模型文件，跳过加载")
    model.to(device)
    model.eval()

    def visualize_predictions(dataset, num_samples=5):
        inv_normalize = transforms.Normalize(
            mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
            std=[1/0.229, 1/0.224, 1/0.225]
        )
        plt.figure(figsize=(15, 5 * num_samples))
        indices = random.sample(range(len(dataset)), num_samples)
        for i, idx in enumerate(indices):
            image, label = dataset[idx]
            if image is None or label is None:
                continue
            img_for_display = inv_normalize(image).permute(1, 2, 0)
            img_for_display = (img_for_display * 255).clamp(0, 255).byte().numpy()
            with torch.no_grad():
                image_tensor = image.unsqueeze(0).to(device)
                prediction = model(image_tensor).squeeze().item()
            plt.subplot(num_samples, 1, i + 1)
            plt.imshow(img_for_display)
            plt.title(f"sample {i+1}: real age = {label:.1f} month, pre_age = {prediction:.1f} month")
            plt.axis('off')
        plt.tight_layout()
        plt.savefig(os.path.join(OUTPUT_PATH, 'prediction_showcase.png'))
        plt.show()

    visualize_predictions(val_dataset)
    print("\n程序结束！请查看生成的图表以及 'prediction_showcase.png', 'error_distribution.png', 'mae_curve.png', 'pred_vs_true.png', 'grad_norm.png', 'error_by_age_bin.csv' 和 'tta_variance.csv' 文件。")

    archive_experiment_results(
        final_mae=best_val_mae,
        optimizer=optimizer,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        epochs_trained=epoch + 1
    )

def archive_experiment_results(final_mae, optimizer, image_size, batch_size, epochs_trained):
    print("\n--- 开始归档本次训练成果 ---")
    learning_rate = optimizer.param_groups[0]['lr']
    tz = ZoneInfo("Asia/Singapore")
    current_time = datetime.now(tz)
    folder_name = current_time.strftime("%Y-%m-%d_%H-%M-%S")
    experiment_path = os.path.join(OUTPUT_PATH, folder_name)
    os.makedirs(experiment_path, exist_ok=True)
    print(f"成功创建归档文件夹: {experiment_path}")

    summary_text = f"""
========================================
      宠物年龄识别模型 - 训练总结
========================================
归档时间: {current_time.strftime("%Y-%m-%d %H:%M:%S %Z")}
--- 训练参数 ---
  - 图像尺寸 (Image Size): {image_size} x {image_size}
  - 批次大小 (Batch Size): {batch_size}
  - 基础学习率 (Base Learning Rate): {BASE_LR}
  - 预热周期 (Warmup Epochs): {WARMUP_EPOCHS}
  - 训练轮数 (Epochs): {epochs_trained}
  - 模型架构 (Architecture): ResNet34
--- 最终结果 ---
  - 最佳验证集平均绝对误差 (Best Validation MAE): {final_mae:.4f} 月
========================================
"""
    summary_file_path = os.path.join(experiment_path, 'summary.txt')
    model_save_path = os.path.join(experiment_path, 'best_model.pth')
    image_save_path = os.path.join(experiment_path, 'prediction_showcase.png')
    error_dist_path = os.path.join(experiment_path, 'error_distribution.png')
    mae_curve_path = os.path.join(experiment_path, 'mae_curve.png')
    pred_true_path = os.path.join(experiment_path, 'pred_vs_true.png')
    grad_norm_path = os.path.join(experiment_path, 'grad_norm.png')
    error_bin_path = os.path.join(experiment_path, 'error_by_age_bin.csv')
    tta_variance_path = os.path.join(experiment_path, 'tta_variance.csv')

    with open(summary_file_path, 'w', encoding='utf-8') as f:
        f.write(summary_text)
    print(f"训练总结已保存至: {summary_file_path}")
    try:
        shutil.copy(os.path.join(OUTPUT_PATH, 'best_model.pth'), model_save_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'prediction_showcase.png'), image_save_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'error_distribution.png'), error_dist_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'mae_curve.png'), mae_curve_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'pred_vs_true.png'), pred_true_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'grad_norm.png'), grad_norm_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'error_by_age_bin.csv'), error_bin_path)
        shutil.copy(os.path.join(OUTPUT_PATH, 'tta_variance.csv'), tta_variance_path)
        print("模型文件、结果图、误差分布图、MAE曲线、预测-真实图、梯度范数图、年龄分段误差和TTA方差已成功备份。")
    except FileNotFoundError as e:
        print(f"归档失败: {e}")
    print("\n🎉 归档完成！所有成果已保存至以下 Kaggle 输出目录:")
    print(f"   {experiment_path}")

if __name__ == '__main__':
    main()
# Out:
# 步骤 1: 项目设置...
# 步骤 2: 解析并加载数据...
#   - 已过滤训练集噪声样本: 94 / 20000 (≈0.5%)
#   - 已过滤验证集噪声样本: 10 / 3000 (≈0.3%)
#   - 找到 19906 个训练样本。
#   - 找到 2990 个验证样本。
# 训练集年龄分布：
#  count    19906.000000
# mean        56.619009
# std         37.430942
# min          1.000000
# 25%         27.000000
# 50%         49.000000
# 75%         81.000000
# max        191.000000
# Name: age, dtype: float64
# 验证集年龄分布：
#  count    2990.000000
# mean       50.437793
# std        35.119582
# min         1.000000
# 25%        25.000000
# 50%        41.000000
# 75%        66.000000
# max       188.000000
# Name: age, dtype: float64
# 步骤 3: 定义模型...
#   - 成功加载权重文件: /kaggle/input/bestmodel/pytorch/default/1/best_model.pth
#   - 加载的 fc 层参数: ['fc.1.weight', 'fc.1.bias']
#   - 模型已移至: cuda
#   - 可训练参数数量: 13114881
# 步骤 4: 开始训练...
# 训练 Epoch [1/80]: 100%|██████████| 1244/1244 [06:09<00:00,  3.36it/s, grad_norm=46.2, loss=22.6, lr=5e-5]
# 验证 Epoch [1/80]: 100%|██████████| 187/187 [00:41<00:00,  4.51it/s]
# Epoch [1/80] -> 训练损失: 23.8685, 训练MAE: 26.0024, 验证MAE: 20.9074, 学习率: 0.000050, 梯度范数: 46.2154, TTA方差: 51.5840
#   - 验证集MAE提升至 20.9074。保存最佳模型: best_model.pth
# 训练 Epoch [2/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.34it/s, grad_norm=45.9, loss=32.4, lr=0.0001]
# 验证 Epoch [2/80]: 100%|██████████| 187/187 [00:28<00:00,  6.46it/s]
# Epoch [2/80] -> 训练损失: 24.1205, 训练MAE: 26.2411, 验证MAE: 21.3719, 学习率: 0.000100, 梯度范数: 45.8911, TTA方差: 26.1687
# 训练 Epoch [3/80]: 100%|██████████| 1244/1244 [04:47<00:00,  4.33it/s, grad_norm=56.6, loss=35.4, lr=0.0001]
# 验证 Epoch [3/80]: 100%|██████████| 187/187 [00:28<00:00,  6.48it/s]
# Epoch [3/80] -> 训练损失: 24.4215, 训练MAE: 26.5441, 验证MAE: 20.9569, 学习率: 0.000100, 梯度范数: 56.6464, TTA方差: 54.1024
# 训练 Epoch [4/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.35it/s, grad_norm=51.7, loss=16.6, lr=0.0001]
# 验证 Epoch [4/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [4/80] -> 训练损失: 24.5649, 训练MAE: 26.6651, 验证MAE: 21.0210, 学习率: 0.000100, 梯度范数: 51.6999, TTA方差: 39.6816
# 训练 Epoch [5/80]: 100%|██████████| 1244/1244 [04:47<00:00,  4.33it/s, grad_norm=74.3, loss=23.3, lr=9.98e-5]
# 验证 Epoch [5/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [5/80] -> 训练损失: 24.5332, 训练MAE: 26.6348, 验证MAE: 22.0824, 学习率: 0.000100, 梯度范数: 74.3346, TTA方差: 21.3670
# 训练 Epoch [6/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.34it/s, grad_norm=77.1, loss=36.7, lr=9.97e-5]
# 验证 Epoch [6/80]: 100%|██████████| 187/187 [00:28<00:00,  6.59it/s]
# Epoch [6/80] -> 训练损失: 24.6741, 训练MAE: 26.7746, 验证MAE: 21.2219, 学习率: 0.000100, 梯度范数: 77.0712, TTA方差: 25.7086
# 训练 Epoch [7/80]: 100%|██████████| 1244/1244 [04:43<00:00,  4.39it/s, grad_norm=60.2, loss=27.9, lr=9.94e-5]
# 验证 Epoch [7/80]: 100%|██████████| 187/187 [00:28<00:00,  6.54it/s]
# Epoch [7/80] -> 训练损失: 24.3932, 训练MAE: 26.4972, 验证MAE: 21.2853, 学习率: 0.000099, 梯度范数: 60.2167, TTA方差: 36.8533
# 训练 Epoch [8/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.34it/s, grad_norm=52.7, loss=24.8, lr=9.9e-5]
# 验证 Epoch [8/80]: 100%|██████████| 187/187 [00:29<00:00,  6.42it/s]
# Epoch [8/80] -> 训练损失: 24.3282, 训练MAE: 26.4868, 验证MAE: 21.7795, 学习率: 0.000099, 梯度范数: 52.7208, TTA方差: 25.8979
# 训练 Epoch [9/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.36it/s, grad_norm=57.8, loss=18.5, lr=9.86e-5]
# 验证 Epoch [9/80]: 100%|██████████| 187/187 [00:28<00:00,  6.54it/s]
# Epoch [9/80] -> 训练损失: 24.4248, 训练MAE: 26.6574, 验证MAE: 22.1703, 学习率: 0.000099, 梯度范数: 57.7651, TTA方差: 33.1821
# 训练 Epoch [10/80]: 100%|██████████| 1244/1244 [04:50<00:00,  4.28it/s, grad_norm=41.8, loss=20.9, lr=9.81e-5]
# 验证 Epoch [10/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [10/80] -> 训练损失: 24.5558, 训练MAE: 26.7908, 验证MAE: 21.4231, 学习率: 0.000098, 梯度范数: 41.8483, TTA方差: 23.3280
# 训练 Epoch [11/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.32it/s, grad_norm=42.6, loss=26.7, lr=9.76e-5]
# 验证 Epoch [11/80]: 100%|██████████| 187/187 [00:29<00:00,  6.45it/s]
# Epoch [11/80] -> 训练损失: 24.6509, 训练MAE: 26.8843, 验证MAE: 21.2309, 学习率: 0.000098, 梯度范数: 42.5786, TTA方差: 26.7175
# 训练 Epoch [12/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.34it/s, grad_norm=42.9, loss=17.7, lr=9.69e-5]
# 验证 Epoch [12/80]: 100%|██████████| 187/187 [00:28<00:00,  6.46it/s]
# Epoch [12/80] -> 训练损失: 24.4634, 训练MAE: 26.7052, 验证MAE: 21.2095, 学习率: 0.000097, 梯度范数: 42.9030, TTA方差: 26.4287
# 训练 Epoch [13/80]: 100%|██████████| 1244/1244 [04:43<00:00,  4.39it/s, grad_norm=44, loss=25.2, lr=9.62e-5]
# 验证 Epoch [13/80]: 100%|██████████| 187/187 [00:28<00:00,  6.54it/s]
# Epoch [13/80] -> 训练损失: 24.5038, 训练MAE: 26.7397, 验证MAE: 21.0984, 学习率: 0.000096, 梯度范数: 43.9946, TTA方差: 29.3829
# 训练 Epoch [14/80]: 100%|██████████| 1244/1244 [04:47<00:00,  4.32it/s, grad_norm=58, loss=26.7, lr=9.54e-5]
# 验证 Epoch [14/80]: 100%|██████████| 187/187 [00:28<00:00,  6.60it/s]
# Epoch [14/80] -> 训练损失: 24.4053, 训练MAE: 26.6345, 验证MAE: 21.7842, 学习率: 0.000095, 梯度范数: 58.0160, TTA方差: 37.0841
# 训练 Epoch [15/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.31it/s, grad_norm=47.2, loss=26.7, lr=9.46e-5]
# 验证 Epoch [15/80]: 100%|██████████| 187/187 [00:28<00:00,  6.50it/s]
# Epoch [15/80] -> 训练损失: 24.4298, 训练MAE: 26.6638, 验证MAE: 22.6950, 学习率: 0.000095, 梯度范数: 47.1938, TTA方差: 24.9942
# 训练 Epoch [16/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.36it/s, grad_norm=65.7, loss=19.1, lr=9.36e-5]
# 验证 Epoch [16/80]: 100%|██████████| 187/187 [00:28<00:00,  6.47it/s]
# Epoch [16/80] -> 训练损失: 24.5321, 训练MAE: 26.7539, 验证MAE: 22.9481, 学习率: 0.000094, 梯度范数: 65.7369, TTA方差: 15.6652
# 训练 Epoch [17/80]: 100%|██████████| 1244/1244 [04:51<00:00,  4.26it/s, grad_norm=53.9, loss=19.8, lr=9.26e-5]
# 验证 Epoch [17/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [17/80] -> 训练损失: 24.5937, 训练MAE: 26.8092, 验证MAE: 21.0738, 学习率: 0.000093, 梯度范数: 53.8811, TTA方差: 33.3324
# 训练 Epoch [18/80]: 100%|██████████| 1244/1244 [04:57<00:00,  4.18it/s, grad_norm=62.6, loss=24.1, lr=9.16e-5]
# 验证 Epoch [18/80]: 100%|██████████| 187/187 [00:29<00:00,  6.34it/s]
# Epoch [18/80] -> 训练损失: 24.6135, 训练MAE: 26.8540, 验证MAE: 21.3495, 学习率: 0.000092, 梯度范数: 62.6402, TTA方差: 24.7945
# 训练 Epoch [19/80]: 100%|██████████| 1244/1244 [04:52<00:00,  4.25it/s, grad_norm=60.5, loss=25.5, lr=9.05e-5]
# 验证 Epoch [19/80]: 100%|██████████| 187/187 [00:29<00:00,  6.42it/s]
# Epoch [19/80] -> 训练损失: 24.5785, 训练MAE: 26.7920, 验证MAE: 21.9110, 学习率: 0.000090, 梯度范数: 60.4886, TTA方差: 19.4629
# 训练 Epoch [20/80]: 100%|██████████| 1244/1244 [04:57<00:00,  4.18it/s, grad_norm=50.1, loss=22.2, lr=8.93e-5]
# 验证 Epoch [20/80]: 100%|██████████| 187/187 [00:28<00:00,  6.53it/s]
# Epoch [20/80] -> 训练损失: 24.5668, 训练MAE: 26.7853, 验证MAE: 21.3136, 学习率: 0.000089, 梯度范数: 50.1209, TTA方差: 24.8995
# 训练 Epoch [21/80]: 100%|██████████| 1244/1244 [04:53<00:00,  4.23it/s, grad_norm=58.1, loss=22.9, lr=8.8e-5]
# 验证 Epoch [21/80]: 100%|██████████| 187/187 [00:28<00:00,  6.49it/s]
# Epoch [21/80] -> 训练损失: 24.7488, 训练MAE: 26.9569, 验证MAE: 21.4590, 学习率: 0.000088, 梯度范数: 58.1257, TTA方差: 28.0011
# 训练 Epoch [22/80]: 100%|██████████| 1244/1244 [04:50<00:00,  4.29it/s, grad_norm=39.3, loss=21.6, lr=8.67e-5]
# 验证 Epoch [22/80]: 100%|██████████| 187/187 [00:28<00:00,  6.49it/s]
# Epoch [22/80] -> 训练损失: 24.8680, 训练MAE: 27.0791, 验证MAE: 21.6238, 学习率: 0.000087, 梯度范数: 39.2945, TTA方差: 20.3681
# 训练 Epoch [23/80]: 100%|██████████| 1244/1244 [04:47<00:00,  4.32it/s, grad_norm=69.2, loss=24.5, lr=8.54e-5]
# 验证 Epoch [23/80]: 100%|██████████| 187/187 [00:28<00:00,  6.50it/s]
# Epoch [23/80] -> 训练损失: 24.7969, 训练MAE: 27.0206, 验证MAE: 21.2149, 学习率: 0.000085, 梯度范数: 69.1578, TTA方差: 33.4904
# 训练 Epoch [24/80]: 100%|██████████| 1244/1244 [04:51<00:00,  4.27it/s, grad_norm=98.4, loss=31.5, lr=8.39e-5]
# 验证 Epoch [24/80]: 100%|██████████| 187/187 [00:29<00:00,  6.37it/s]
# Epoch [24/80] -> 训练损失: 24.8288, 训练MAE: 27.0335, 验证MAE: 21.7594, 学习率: 0.000084, 梯度范数: 98.4155, TTA方差: 24.7675
# 训练 Epoch [25/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.35it/s, grad_norm=91.8, loss=30, lr=8.25e-5]
# 验证 Epoch [25/80]: 100%|██████████| 187/187 [00:28<00:00,  6.47it/s]
# Epoch [25/80] -> 训练损失: 24.8712, 训练MAE: 27.0804, 验证MAE: 21.2321, 学习率: 0.000082, 梯度范数: 91.8113, TTA方差: 32.6373
# 训练 Epoch [26/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.36it/s, grad_norm=77, loss=14.7, lr=8.1e-5]
# 验证 Epoch [26/80]: 100%|██████████| 187/187 [00:28<00:00,  6.63it/s]
# Epoch [26/80] -> 训练损失: 24.9348, 训练MAE: 27.1343, 验证MAE: 21.5858, 学习率: 0.000081, 梯度范数: 77.0031, TTA方差: 30.2826
# 训练 Epoch [27/80]: 100%|██████████| 1244/1244 [04:51<00:00,  4.27it/s, grad_norm=79.2, loss=21.6, lr=7.94e-5]
# 验证 Epoch [27/80]: 100%|██████████| 187/187 [00:29<00:00,  6.42it/s]
# Epoch [27/80] -> 训练损失: 24.7351, 训练MAE: 26.9539, 验证MAE: 21.7663, 学习率: 0.000079, 梯度范数: 79.2077, TTA方差: 22.1564
# 训练 Epoch [28/80]: 100%|██████████| 1244/1244 [04:50<00:00,  4.29it/s, grad_norm=53.4, loss=19.4, lr=7.78e-5]
# 验证 Epoch [28/80]: 100%|██████████| 187/187 [00:28<00:00,  6.52it/s]
# Epoch [28/80] -> 训练损失: 24.9619, 训练MAE: 27.1318, 验证MAE: 21.4159, 学习率: 0.000078, 梯度范数: 53.3893, TTA方差: 21.9120
# 训练 Epoch [29/80]: 100%|██████████| 1244/1244 [04:49<00:00,  4.30it/s, grad_norm=92.8, loss=22.8, lr=7.61e-5]
# 验证 Epoch [29/80]: 100%|██████████| 187/187 [00:27<00:00,  6.79it/s]
# Epoch [29/80] -> 训练损失: 25.0133, 训练MAE: 27.2082, 验证MAE: 21.5598, 学习率: 0.000076, 梯度范数: 92.7616, TTA方差: 20.4865
# 训练 Epoch [30/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.35it/s, grad_norm=57.7, loss=22.6, lr=7.44e-5]
# 验证 Epoch [30/80]: 100%|██████████| 187/187 [00:28<00:00,  6.62it/s]
# Epoch [30/80] -> 训练损失: 25.0904, 训练MAE: 27.2901, 验证MAE: 22.4601, 学习率: 0.000074, 梯度范数: 57.7077, TTA方差: 20.5700
# 训练 Epoch [31/80]: 100%|██████████| 1244/1244 [04:51<00:00,  4.26it/s, grad_norm=39.1, loss=37.5, lr=7.27e-5]
# 验证 Epoch [31/80]: 100%|██████████| 187/187 [00:28<00:00,  6.62it/s]
# Epoch [31/80] -> 训练损失: 24.9737, 训练MAE: 27.1647, 验证MAE: 21.8721, 学习率: 0.000073, 梯度范数: 39.1351, TTA方差: 19.6200
# 训练 Epoch [32/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.32it/s, grad_norm=42.4, loss=22.1, lr=7.09e-5]
# 验证 Epoch [32/80]: 100%|██████████| 187/187 [00:29<00:00,  6.29it/s]
# Epoch [32/80] -> 训练损失: 25.1704, 训练MAE: 27.3689, 验证MAE: 21.3869, 学习率: 0.000071, 梯度范数: 42.4237, TTA方差: 24.7637
# 训练 Epoch [33/80]: 100%|██████████| 1244/1244 [04:49<00:00,  4.29it/s, grad_norm=65.7, loss=24.3, lr=6.91e-5]
# 验证 Epoch [33/80]: 100%|██████████| 187/187 [00:28<00:00,  6.54it/s]
# Epoch [33/80] -> 训练损失: 25.0962, 训练MAE: 27.2863, 验证MAE: 21.9316, 学习率: 0.000069, 梯度范数: 65.7020, TTA方差: 21.6568
# 训练 Epoch [34/80]: 100%|██████████| 1244/1244 [04:43<00:00,  4.39it/s, grad_norm=93.8, loss=17.6, lr=6.73e-5]
# 验证 Epoch [34/80]: 100%|██████████| 187/187 [00:28<00:00,  6.47it/s]
# Epoch [34/80] -> 训练损失: 25.2422, 训练MAE: 27.4266, 验证MAE: 21.3245, 学习率: 0.000067, 梯度范数: 93.8072, TTA方差: 28.0436
# 训练 Epoch [35/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=46.9, loss=31.7, lr=6.55e-5]
# 验证 Epoch [35/80]: 100%|██████████| 187/187 [00:28<00:00,  6.52it/s]
# Epoch [35/80] -> 训练损失: 25.0892, 训练MAE: 27.2710, 验证MAE: 21.4675, 学习率: 0.000065, 梯度范数: 46.8985, TTA方差: 35.2756
# 训练 Epoch [36/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=83.7, loss=30.2, lr=6.36e-5]
# 验证 Epoch [36/80]: 100%|██████████| 187/187 [00:28<00:00,  6.65it/s]
# Epoch [36/80] -> 训练损失: 25.0344, 训练MAE: 27.2145, 验证MAE: 22.1640, 学习率: 0.000064, 梯度范数: 83.7486, TTA方差: 12.2537
# 训练 Epoch [37/80]: 100%|██████████| 1244/1244 [04:41<00:00,  4.42it/s, grad_norm=63, loss=20.9, lr=6.17e-5]
# 验证 Epoch [37/80]: 100%|██████████| 187/187 [00:27<00:00,  6.71it/s]
# Epoch [37/80] -> 训练损失: 25.2424, 训练MAE: 27.4109, 验证MAE: 21.9063, 学习率: 0.000062, 梯度范数: 63.0184, TTA方差: 26.7259
# 训练 Epoch [38/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=85, loss=21.7, lr=5.98e-5]
# 验证 Epoch [38/80]: 100%|██████████| 187/187 [00:28<00:00,  6.59it/s]
# Epoch [38/80] -> 训练损失: 25.2283, 训练MAE: 27.4079, 验证MAE: 21.8913, 学习率: 0.000060, 梯度范数: 84.9674, TTA方差: 16.8239
# 训练 Epoch [39/80]: 100%|██████████| 1244/1244 [04:56<00:00,  4.19it/s, grad_norm=94.6, loss=15.1, lr=5.78e-5]
# 验证 Epoch [39/80]: 100%|██████████| 187/187 [00:28<00:00,  6.54it/s]
# Epoch [39/80] -> 训练损失: 25.1197, 训练MAE: 27.3064, 验证MAE: 21.7202, 学习率: 0.000058, 梯度范数: 94.6276, TTA方差: 23.9923
# 训练 Epoch [40/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.31it/s, grad_norm=73, loss=26.4, lr=5.59e-5]
# 验证 Epoch [40/80]: 100%|██████████| 187/187 [00:28<00:00,  6.57it/s]
# Epoch [40/80] -> 训练损失: 25.3258, 训练MAE: 27.5079, 验证MAE: 21.5871, 学习率: 0.000056, 梯度范数: 72.9835, TTA方差: 24.0990
# 训练 Epoch [41/80]: 100%|██████████| 1244/1244 [04:54<00:00,  4.23it/s, grad_norm=35.5, loss=45, lr=5.39e-5]
# 验证 Epoch [41/80]: 100%|██████████| 187/187 [00:28<00:00,  6.56it/s]
# Epoch [41/80] -> 训练损失: 25.6231, 训练MAE: 27.7644, 验证MAE: 21.5970, 学习率: 0.000054, 梯度范数: 35.5274, TTA方差: 21.9332
# 训练 Epoch [42/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.31it/s, grad_norm=94.2, loss=17.4, lr=5.2e-5]
# 验证 Epoch [42/80]: 100%|██████████| 187/187 [00:29<00:00,  6.31it/s]
# Epoch [42/80] -> 训练损失: 25.3971, 训练MAE: 27.5837, 验证MAE: 22.0865, 学习率: 0.000052, 梯度范数: 94.1575, TTA方差: 14.4826
# 训练 Epoch [43/80]: 100%|██████████| 1244/1244 [04:42<00:00,  4.41it/s, grad_norm=58.9, loss=30.8, lr=5e-5]
# 验证 Epoch [43/80]: 100%|██████████| 187/187 [00:28<00:00,  6.60it/s]
# Epoch [43/80] -> 训练损失: 25.5412, 训练MAE: 27.6605, 验证MAE: 21.5274, 学习率: 0.000050, 梯度范数: 58.8643, TTA方差: 19.3783
# 训练 Epoch [44/80]: 100%|██████████| 1244/1244 [04:43<00:00,  4.39it/s, grad_norm=56.2, loss=27.3, lr=4.8e-5]
# 验证 Epoch [44/80]: 100%|██████████| 187/187 [00:28<00:00,  6.50it/s]
# Epoch [44/80] -> 训练损失: 25.5086, 训练MAE: 27.6686, 验证MAE: 21.7478, 学习率: 0.000048, 梯度范数: 56.2350, TTA方差: 18.0397
# 训练 Epoch [45/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.36it/s, grad_norm=83.2, loss=33.4, lr=4.61e-5]
# 验证 Epoch [45/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [45/80] -> 训练损失: 25.3959, 训练MAE: 27.5642, 验证MAE: 22.4090, 学习率: 0.000046, 梯度范数: 83.1995, TTA方差: 12.7672
# 训练 Epoch [46/80]: 100%|██████████| 1244/1244 [04:50<00:00,  4.29it/s, grad_norm=106, loss=37.4, lr=4.41e-5]
# 验证 Epoch [46/80]: 100%|██████████| 187/187 [00:28<00:00,  6.55it/s]
# Epoch [46/80] -> 训练损失: 25.5988, 训练MAE: 27.7534, 验证MAE: 21.1143, 学习率: 0.000044, 梯度范数: 106.4435, TTA方差: 29.5272
# 训练 Epoch [47/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=49.1, loss=20.7, lr=4.22e-5]
# 验证 Epoch [47/80]: 100%|██████████| 187/187 [00:28<00:00,  6.64it/s]
# Epoch [47/80] -> 训练损失: 25.4963, 训练MAE: 27.6403, 验证MAE: 22.3274, 学习率: 0.000042, 梯度范数: 49.1082, TTA方差: 14.3499
# 训练 Epoch [48/80]: 100%|██████████| 1244/1244 [04:41<00:00,  4.42it/s, grad_norm=87.2, loss=30.1, lr=4.02e-5]
# 验证 Epoch [48/80]: 100%|██████████| 187/187 [00:28<00:00,  6.52it/s]
# Epoch [48/80] -> 训练损失: 25.2776, 训练MAE: 27.4316, 验证MAE: 21.5436, 学习率: 0.000040, 梯度范数: 87.2331, TTA方差: 22.2707
# 训练 Epoch [49/80]: 100%|██████████| 1244/1244 [04:41<00:00,  4.41it/s, grad_norm=84.4, loss=23.3, lr=3.83e-5]
# 验证 Epoch [49/80]: 100%|██████████| 187/187 [00:28<00:00,  6.57it/s]
# Epoch [49/80] -> 训练损失: 25.6807, 训练MAE: 27.8083, 验证MAE: 21.4337, 学习率: 0.000038, 梯度范数: 84.4322, TTA方差: 21.4456
# 训练 Epoch [50/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=117, loss=19.1, lr=3.64e-5]
# 验证 Epoch [50/80]: 100%|██████████| 187/187 [00:28<00:00,  6.60it/s]
# Epoch [50/80] -> 训练损失: 25.7493, 训练MAE: 27.8860, 验证MAE: 21.5789, 学习率: 0.000036, 梯度范数: 116.8475, TTA方差: 18.2157
# 训练 Epoch [51/80]: 100%|██████████| 1244/1244 [04:45<00:00,  4.36it/s, grad_norm=87.4, loss=26.5, lr=3.45e-5]
# 验证 Epoch [51/80]: 100%|██████████| 187/187 [00:29<00:00,  6.40it/s]
# Epoch [51/80] -> 训练损失: 25.6968, 训练MAE: 27.8346, 验证MAE: 22.5254, 学习率: 0.000035, 梯度范数: 87.4189, TTA方差: 14.7342
# 训练 Epoch [52/80]: 100%|██████████| 1244/1244 [04:57<00:00,  4.18it/s, grad_norm=66.9, loss=26.1, lr=3.27e-5]
# 验证 Epoch [52/80]: 100%|██████████| 187/187 [00:28<00:00,  6.58it/s]
# Epoch [52/80] -> 训练损失: 25.8279, 训练MAE: 27.9445, 验证MAE: 22.1366, 学习率: 0.000033, 梯度范数: 66.8888, TTA方差: 19.2931
# 训练 Epoch [53/80]: 100%|██████████| 1244/1244 [04:47<00:00,  4.33it/s, grad_norm=92.2, loss=25.6, lr=3.09e-5]
# 验证 Epoch [53/80]: 100%|██████████| 187/187 [00:28<00:00,  6.52it/s]
# Epoch [53/80] -> 训练损失: 25.9943, 训练MAE: 28.1005, 验证MAE: 21.8358, 学习率: 0.000031, 梯度范数: 92.1910, TTA方差: 18.4161
# 训练 Epoch [54/80]: 100%|██████████| 1244/1244 [04:49<00:00,  4.29it/s, grad_norm=69.9, loss=22.5, lr=2.91e-5]
# 验证 Epoch [54/80]: 100%|██████████| 187/187 [00:29<00:00,  6.34it/s]
# Epoch [54/80] -> 训练损失: 25.8772, 训练MAE: 28.0067, 验证MAE: 22.7375, 学习率: 0.000029, 梯度范数: 69.8947, TTA方差: 17.9933
# 训练 Epoch [55/80]: 100%|██████████| 1244/1244 [04:56<00:00,  4.20it/s, grad_norm=64, loss=19.5, lr=2.73e-5]
# 验证 Epoch [55/80]: 100%|██████████| 187/187 [00:29<00:00,  6.34it/s]
# Epoch [55/80] -> 训练损失: 26.1601, 训练MAE: 28.2643, 验证MAE: 22.4948, 学习率: 0.000027, 梯度范数: 63.9840, TTA方差: 13.7858
# 训练 Epoch [56/80]: 100%|██████████| 1244/1244 [04:57<00:00,  4.18it/s, grad_norm=81.8, loss=24.5, lr=2.56e-5]
# 验证 Epoch [56/80]: 100%|██████████| 187/187 [00:29<00:00,  6.33it/s]
# Epoch [56/80] -> 训练损失: 26.2422, 训练MAE: 28.3300, 验证MAE: 21.8827, 学习率: 0.000026, 梯度范数: 81.8093, TTA方差: 17.0484
# 训练 Epoch [57/80]: 100%|██████████| 1244/1244 [04:53<00:00,  4.25it/s, grad_norm=105, loss=19.7, lr=2.39e-5]
# 验证 Epoch [57/80]: 100%|██████████| 187/187 [00:28<00:00,  6.46it/s]
# Epoch [57/80] -> 训练损失: 26.3518, 训练MAE: 28.4438, 验证MAE: 22.2920, 学习率: 0.000024, 梯度范数: 105.3413, TTA方差: 14.6457
# 训练 Epoch [58/80]: 100%|██████████| 1244/1244 [04:52<00:00,  4.26it/s, grad_norm=78.5, loss=29.7, lr=2.22e-5]
# 验证 Epoch [58/80]: 100%|██████████| 187/187 [00:29<00:00,  6.43it/s]
# Epoch [58/80] -> 训练损失: 26.3494, 训练MAE: 28.4189, 验证MAE: 22.8781, 学习率: 0.000022, 梯度范数: 78.5079, TTA方差: 12.2365
# 训练 Epoch [59/80]: 100%|██████████| 1244/1244 [04:54<00:00,  4.23it/s, grad_norm=46.5, loss=38.5, lr=2.06e-5]
# 验证 Epoch [59/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [59/80] -> 训练损失: 26.4449, 训练MAE: 28.5323, 验证MAE: 22.7046, 学习率: 0.000021, 梯度范数: 46.5321, TTA方差: 15.0824
# 训练 Epoch [60/80]: 100%|██████████| 1244/1244 [05:15<00:00,  3.94it/s, grad_norm=70.4, loss=35.5, lr=1.9e-5]
# 验证 Epoch [60/80]: 100%|██████████| 187/187 [00:28<00:00,  6.45it/s]
# Epoch [60/80] -> 训练损失: 26.6122, 训练MAE: 28.6704, 验证MAE: 21.8557, 学习率: 0.000019, 梯度范数: 70.4053, TTA方差: 14.3123
# 训练 Epoch [61/80]: 100%|██████████| 1244/1244 [05:15<00:00,  3.95it/s, grad_norm=103, loss=11, lr=1.75e-5]
# 验证 Epoch [61/80]: 100%|██████████| 187/187 [00:28<00:00,  6.58it/s]
# Epoch [61/80] -> 训练损失: 26.5961, 训练MAE: 28.6545, 验证MAE: 21.4862, 学习率: 0.000018, 梯度范数: 102.5832, TTA方差: 20.1626
# 训练 Epoch [62/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.31it/s, grad_norm=124, loss=20.6, lr=1.61e-5]
# 验证 Epoch [62/80]: 100%|██████████| 187/187 [00:28<00:00,  6.48it/s]
# Epoch [62/80] -> 训练损失: 26.4733, 训练MAE: 28.5267, 验证MAE: 22.4590, 学习率: 0.000016, 梯度范数: 123.6159, TTA方差: 10.4958
# 训练 Epoch [63/80]: 100%|██████████| 1244/1244 [04:50<00:00,  4.29it/s, grad_norm=123, loss=25.7, lr=1.46e-5]
# 验证 Epoch [63/80]: 100%|██████████| 187/187 [00:28<00:00,  6.49it/s]
# Epoch [63/80] -> 训练损失: 26.5772, 训练MAE: 28.6484, 验证MAE: 22.7187, 学习率: 0.000015, 梯度范数: 122.7102, TTA方差: 14.2629
# 训练 Epoch [64/80]: 100%|██████████| 1244/1244 [04:48<00:00,  4.32it/s, grad_norm=135, loss=25.8, lr=1.33e-5]
# 验证 Epoch [64/80]: 100%|██████████| 187/187 [00:27<00:00,  6.70it/s]
# Epoch [64/80] -> 训练损失: 26.7348, 训练MAE: 28.7889, 验证MAE: 22.3657, 学习率: 0.000013, 梯度范数: 134.8769, TTA方差: 11.9562
# 训练 Epoch [65/80]: 100%|██████████| 1244/1244 [04:41<00:00,  4.42it/s, grad_norm=99.8, loss=24.4, lr=1.2e-5]
# 验证 Epoch [65/80]: 100%|██████████| 187/187 [00:28<00:00,  6.49it/s]
# Epoch [65/80] -> 训练损失: 26.7242, 训练MAE: 28.7637, 验证MAE: 23.4471, 学习率: 0.000012, 梯度范数: 99.8234, TTA方差: 9.8786
# 训练 Epoch [66/80]: 100%|██████████| 1244/1244 [04:39<00:00,  4.44it/s, grad_norm=71.3, loss=28.1, lr=1.07e-5]
# 验证 Epoch [66/80]: 100%|██████████| 187/187 [00:28<00:00,  6.63it/s]
# Epoch [66/80] -> 训练损失: 26.8209, 训练MAE: 28.8654, 验证MAE: 22.6348, 学习率: 0.000011, 梯度范数: 71.2583, TTA方差: 13.4509
# 训练 Epoch [67/80]: 100%|██████████| 1244/1244 [04:39<00:00,  4.46it/s, grad_norm=73.6, loss=27.7, lr=9.55e-6]
# 验证 Epoch [67/80]: 100%|██████████| 187/187 [00:28<00:00,  6.63it/s]
# Epoch [67/80] -> 训练损失: 26.8105, 训练MAE: 28.8359, 验证MAE: 22.1397, 学习率: 0.000010, 梯度范数: 73.6269, TTA方差: 13.9346
# 训练 Epoch [68/80]: 100%|██████████| 1244/1244 [04:39<00:00,  4.45it/s, grad_norm=118, loss=23.2, lr=8.43e-6]
# 验证 Epoch [68/80]: 100%|██████████| 187/187 [00:28<00:00,  6.60it/s]
# Epoch [68/80] -> 训练损失: 26.7394, 训练MAE: 28.7875, 验证MAE: 22.6444, 学习率: 0.000008, 梯度范数: 118.3058, TTA方差: 11.5707
# 训练 Epoch [69/80]: 100%|██████████| 1244/1244 [04:40<00:00,  4.43it/s, grad_norm=15.2, loss=42.5, lr=7.37e-6]
# 验证 Epoch [69/80]: 100%|██████████| 187/187 [00:28<00:00,  6.61it/s]
# Epoch [69/80] -> 训练损失: 26.8630, 训练MAE: 28.8937, 验证MAE: 22.9660, 学习率: 0.000007, 梯度范数: 15.1542, TTA方差: 9.1388
# 训练 Epoch [70/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.38it/s, grad_norm=89.3, loss=28.9, lr=6.38e-6]
# 验证 Epoch [70/80]: 100%|██████████| 187/187 [00:28<00:00,  6.49it/s]
# Epoch [70/80] -> 训练损失: 27.0376, 训练MAE: 29.0533, 验证MAE: 22.6922, 学习率: 0.000006, 梯度范数: 89.2591, TTA方差: 11.1050
# 训练 Epoch [71/80]: 100%|██████████| 1244/1244 [04:46<00:00,  4.34it/s, grad_norm=87.9, loss=21.8, lr=5.45e-6]
# 验证 Epoch [71/80]: 100%|██████████| 187/187 [00:28<00:00,  6.53it/s]
# Epoch [71/80] -> 训练损失: 26.9497, 训练MAE: 28.9698, 验证MAE: 23.2152, 学习率: 0.000005, 梯度范数: 87.8652, TTA方差: 8.2528
# 训练 Epoch [72/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.38it/s, grad_norm=122, loss=32, lr=4.59e-6]
# 验证 Epoch [72/80]: 100%|██████████| 187/187 [00:29<00:00,  6.39it/s]
# Epoch [72/80] -> 训练损失: 27.0489, 训练MAE: 29.0815, 验证MAE: 22.6172, 学习率: 0.000005, 梯度范数: 121.9529, TTA方差: 11.1578
# 训练 Epoch [73/80]: 100%|██████████| 1244/1244 [04:44<00:00,  4.37it/s, grad_norm=130, loss=21.5, lr=3.81e-6]
# 验证 Epoch [73/80]: 100%|██████████| 187/187 [00:28<00:00,  6.51it/s]
# Epoch [73/80] -> 训练损失: 27.1770, 训练MAE: 29.1781, 验证MAE: 22.6023, 学习率: 0.000004, 梯度范数: 129.6615, TTA方差: 11.0267
# 训练 Epoch [74/80]: 100%|██████████| 1244/1244 [04:53<00:00,  4.24it/s, grad_norm=143, loss=30, lr=3.09e-6]
# 验证 Epoch [74/80]: 100%|██████████| 187/187 [00:30<00:00,  6.09it/s]
# Epoch [74/80] -> 训练损失: 27.1918, 训练MAE: 29.1913, 验证MAE: 23.0437, 学习率: 0.000003, 梯度范数: 143.3811, TTA方差: 11.8598
# 训练 Epoch [75/80]: 100%|██████████| 1244/1244 [05:07<00:00,  4.04it/s, grad_norm=73.7, loss=35.2, lr=2.45e-6]
# 验证 Epoch [75/80]: 100%|██████████| 187/187 [00:31<00:00,  6.01it/s]
# Epoch [75/80] -> 训练损失: 27.2495, 训练MAE: 29.2424, 验证MAE: 22.9746, 学习率: 0.000002, 梯度范数: 73.7213, TTA方差: 8.6926
# 训练 Epoch [76/80]: 100%|██████████| 1244/1244 [05:07<00:00,  4.04it/s, grad_norm=108, loss=22.7, lr=1.88e-6]
# 验证 Epoch [76/80]: 100%|██████████| 187/187 [00:30<00:00,  6.10it/s]
# Epoch [76/80] -> 训练损失: 27.1501, 训练MAE: 29.1419, 验证MAE: 22.8114, 学习率: 0.000002, 梯度范数: 108.3178, TTA方差: 9.7456
# 训练 Epoch [77/80]: 100%|██████████| 1244/1244 [05:09<00:00,  4.01it/s, grad_norm=123, loss=33, lr=1.38e-6]
# 验证 Epoch [77/80]: 100%|██████████| 187/187 [00:30<00:00,  6.13it/s]
# Epoch [77/80] -> 训练损失: 27.2489, 训练MAE: 29.2449, 验证MAE: 23.0538, 学习率: 0.000001, 梯度范数: 123.4850, TTA方差: 10.6751
# 训练 Epoch [78/80]: 100%|██████████| 1244/1244 [05:02<00:00,  4.11it/s, grad_norm=89.5, loss=21.3, lr=9.61e-7]
# 验证 Epoch [78/80]: 100%|██████████| 187/187 [00:30<00:00,  6.05it/s]
# Epoch [78/80] -> 训练损失: 27.1500, 训练MAE: 29.1568, 验证MAE: 22.8137, 学习率: 0.000001, 梯度范数: 89.5399, TTA方差: 9.1117
# 训练 Epoch [79/80]: 100%|██████████| 1244/1244 [05:07<00:00,  4.05it/s, grad_norm=205, loss=23, lr=6.16e-7]
# 验证 Epoch [79/80]: 100%|██████████| 187/187 [00:31<00:00,  5.96it/s]
# Epoch [79/80] -> 训练损失: 27.1746, 训练MAE: 29.1886, 验证MAE: 22.8906, 学习率: 0.000001, 梯度范数: 205.4052, TTA方差: 10.5637
# 训练 Epoch [80/80]: 100%|██████████| 1244/1244 [05:07<00:00,  4.05it/s, grad_norm=95.6, loss=37.4, lr=3.47e-7]
# 验证 Epoch [80/80]: 100%|██████████| 187/187 [00:30<00:00,  6.05it/s]
# Epoch [80/80] -> 训练损失: 27.1809, 训练MAE: 29.1882, 验证MAE: 22.7462, 学习率: 0.000000, 梯度范数: 95.6112, TTA方差: 9.0829
#
# 训练完成。最佳验证集MAE: 20.9074 (Epoch 1)
# 验证集误差分布统计：
#  count    2990.000000
# mean       22.746180
# std        24.997339
# min         0.004097
# 25%         6.075672
# 50%        13.955772
# 75%        29.183494
# max       144.930786
# dtype: float64
# TTA方差统计：
#  count    80.000000
# mean     20.808058
# std       9.360011
# min       8.252769
# 25%      13.702047
# 50%      19.891342
# 75%      25.755932
# max      54.102448
# dtype: float64
# 按年龄分段的平均误差：
#                 mean_error  count
# age_bin
# (0.999, 25.0]   13.712284  776.0
# (25.0, 41.0]     6.467817  754.0
# (41.0, 66.0]    13.674575  717.0
# (66.0, 188.0]   57.454838  743.0
#
# 步骤 5: 最终评估与结果展示...
#   - 成功加载最佳模型: best_model.pth
# 程序结束！请查看生成的图表以及 'prediction_showcase.png', 'error_distribution.png', 'mae_curve.png', 'pred_vs_true.png', 'grad_norm.png', 'error_by_age_bin.csv' 和 'tta_variance.csv' 文件。
#
# --- 开始归档本次训练成果 ---
# 成功创建归档文件夹: /kaggle/working/2025-07-12_04-33-36
# 训练总结已保存至: /kaggle/working/2025-07-12_04-33-36/summary.txt
# 模型文件、结果图、误差分布图、MAE曲线、预测-真实图、梯度范数图、年龄分段误差和TTA方差已成功备份。
#
# 🎉 归档完成！所有成果已保存至以下 Kaggle 输出目录:
#    /kaggle/working/2025-07-12_04-33-36
